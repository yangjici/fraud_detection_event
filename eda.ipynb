# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_json('data.json')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14337 entries, 0 to 14336
# Data columns (total 44 columns):
# acct_type             14337 non-null object
# approx_payout_date    14337 non-null int64
# body_length           14337 non-null int64
# channels              14337 non-null int64
# country               14256 non-null object
# currency              14337 non-null object
# delivery_method       14321 non-null float64
# description           14337 non-null object
# email_domain          14337 non-null object
# event_created         14337 non-null int64
# event_end             14337 non-null int64
# event_published       14238 non-null float64
# event_start           14337 non-null int64
# fb_published          14337 non-null int64
# gts                   14337 non-null float64
# has_analytics         14337 non-null int64
# has_header            8928 non-null float64
# has_logo              14337 non-null int64
# listed                14337 non-null object
# ...

# %%
df.head(10)
# Out:
#          acct_type  approx_payout_date  body_length  channels country  \
# 0  fraudster_event          1266062400         3852         5      US
# 1          premium          1296720000         3499         0      US
# 2          premium          1296172800         2601         8      US
# 3          premium          1388966400        12347         6      IE
# 4          premium          1297900800         2417        11      US
# 5          premium          1300496400          117         6      US
# 6          premium          1297909800           28         5      US
# 7          premium          1296709200          974        12      US
# 8          premium          1298185200         4388         4      US
# 9          premium          1297314000          974        12      US
#
#   currency  delivery_method  \
# 0      USD              0.0
# 1      USD              1.0
# 2      USD              1.0
# 3      EUR              1.0
# 4      USD              0.0
# ...

# %%
df.describe()
# Out:
# /Users/vynguyen/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        approx_payout_date   body_length      channels  delivery_method  \
# count        1.433700e+04  14337.000000  14337.000000     14321.000000
# mean         1.350933e+09   3672.521936      6.176676         0.439564
# std          2.401300e+07   5758.113003      3.860333         0.591487
# min          1.171256e+09      0.000000      0.000000         0.000000
# 25%          1.334221e+09    750.000000      5.000000              NaN
# 50%          1.355805e+09   1990.000000      6.000000              NaN
# 75%          1.370646e+09   4280.000000      8.000000              NaN
# max          1.523488e+09  65535.000000     13.000000         3.000000
#
#        event_created     event_end  event_published   event_start  \
# count   1.433700e+04  1.433700e+04     1.423800e+04  1.433700e+04
# ...

# %%
df['acct_type'].unique()
# Out:
# array([u'fraudster_event', u'premium', u'spammer_warn', u'fraudster',
#        u'spammer_limited', u'spammer_noinvite', u'locked', u'tos_lock',
#        u'tos_warn', u'fraudster_att', u'spammer_web', u'spammer'], dtype=object)

# %%
df['user_created'].value_counts().head()
# Out:
# 1259160686    47
# 1308777954    46
# 1313805994    44
# 1264446071    39
# 1299651441    38
# Name: user_created, dtype: int64

# %%
df.groupby('acct_type')['user_created'].count()
# Out:
# acct_type
# fraudster             437
# fraudster_att           5
# fraudster_event       851
# locked                 54
# premium             12373
# spammer                 1
# spammer_limited       218
# spammer_noinvite       84
# spammer_warn          144
# spammer_web             2
# tos_lock               77
# tos_warn               91
# Name: user_created, dtype: int64

# %%
df.groupby('acct_type').count()
# Out:
#                   approx_payout_date  body_length  channels  country  \
# acct_type
# fraudster                        437          437       437      437
# fraudster_att                      5            5         5        5
# fraudster_event                  851          851       851      851
# locked                            54           54        54       54
# premium                        12373        12373     12373    12297
# spammer                            1            1         1        1
# spammer_limited                  218          218       218      214
# spammer_noinvite                  84           84        84       84
# spammer_warn                     144          144       144      143
# spammer_web                        2            2         2        2
# tos_lock                          77           77        77       77
# tos_warn                          91           91        91       91
#
# ...

# %%
df.to_csv('data.csv', encoding='utf-8')

# %%
df[(df['acct_type']=='locked')]['description'].iloc[0]
# Out:
# u'<p style="text-align: center;"><span style="font-size: large;"><strong>A new era of tattoo shows is here!</strong></span><br /><br />Since the begining of time man has been drawn to the tattoo, now this art form has created a global culture all of it\'s own. InkFest Live is the new face of tattooing. Gone are the days of shady back room tattooists, today\'s artists are true pros creating mind blowing works of skin art. InkFest Live showcases these artists in an exciting urban environment that will entertain and enlighten. InkFest Live is the first of it\'s kind expo, combining the best tattoo artists, graffiti, vendors, custom cars &amp; bikes and live music performances. 2012 Begins in Concord, NC February 3rd-5th 2012.</p>\r\n<p style="text-align: -webkit-auto;">\xa0</p>'

# %%
df[(df['acct_type']=='locked')].iloc[0]
# Out:
# acct_type                                                        locked
# approx_payout_date                                           1328925600
# body_length                                                         775
# channels                                                             11
# country                                                              US
# currency                                                            USD
# delivery_method                                                       1
# description           <p style="text-align: center;"><span style="fo...
# email_domain                                            inkfestlive.com
# event_created                                                1326313347
# event_end                                                    1328493600
# event_published                                             1.32631e+09
# event_start                                                  1328475600
# ...

# %%
df[(df['acct_type']=='fraudster_event')].iloc[0]
# Out:
# acct_type                                               fraudster_event
# approx_payout_date                                           1266062400
# body_length                                                        3852
# channels                                                              5
# country                                                              US
# currency                                                            USD
# delivery_method                                                       0
# description           <p><a href="http://s432.photobucket.com/albums...
# email_domain                                                  gmail.com
# event_created                                                1262739706
# event_end                                                    1265630400
# event_published                                             1.26311e+09
# event_start                                                  1265594400
# ...

# %%
df.groupby(['acct_type', 'has_logo'])['channels'].count()
# Out:
# acct_type         has_logo
# fraudster         0             155
#                   1             282
# fraudster_att     0               1
#                   1               4
# fraudster_event   0             302
#                   1             549
# locked            0              11
#                   1              43
# premium           0            1719
#                   1           10654
# spammer           1               1
# spammer_limited   0              26
#                   1             192
# spammer_noinvite  0               8
#                   1              76
# spammer_warn      0              22
#                   1             122
# spammer_web       1               2
# tos_lock          0               6
#                   1              71
# tos_warn          0              14
#                   1              77
# Name: channels, dtype: int64

# %%
fraud_flags = ['fraudster_event', 'fraudster', 'fraudster_att']

df['Fraud'] = df['acct_type'].map(lambda x: 1 if x in fraud_flags else 0)

# %%
df['payout_type'].value_counts()
# Out:
# ACH      10666
# CHECK     3178
#            493
# Name: payout_type, dtype: int64

# %%
df['country'].value_counts()
# Out:
# US    9234
# GB    2083
# CA    1262
# AU     742
#        316
# NZ      73
# IE      48
# MA      47
# DE      43
# FR      40
# NL      36
# VN      32
# ES      27
# A1      25
# PK      22
# HU      18
# BE      18
# PH      15
# ID      12
# PR      10
# CI       9
# RO       8
# AT       8
# AR       8
# CZ       7
# NG       7
# SG       7
# TH       6
# CH       6
# DZ       6
#       ...
# MX       2
# RU       2
# TR       2
# GR       2
# QA       2
# UY       2
# NA       2
# PT       2
# CM       2
# CN       2
# SI       1
# IM       1
# IS       1
# VI       1
# VE       1
# AE       1
# CR       1
# BB       1
# IL       1
# BS       1
# JE       1
# LB       1
# NI       1
# PE       1
# TJ       1
# EC       1
# KE       1
# PS       1
# DK       1
# CO       1
# Name: country, dtype: int64

# %%
df['listed'].value_counts()
# Out:
# y    12291
# n     2046
# Name: listed, dtype: int64

# %%
df['payout_type'].value_counts()
# Out:
# ACH      10666
# CHECK     3178
#            493
# Name: payout_type, dtype: int64

# %%
df['venue_country'].value_counts()
# Out:
# US    8336
# GB    1838
# CA    1134
#        876
# AU     683
# FR      52
# NZ      50
# IE      44
# DE      36
# NL      30
# ES      20
# MA      18
# PH      15
# BE      15
# AR       9
# ID       9
# VN       6
# AE       5
# PR       5
# AT       4
# ZA       4
# PL       3
# TR       3
# PK       3
# SG       3
# KE       3
# TH       3
# HU       3
# BS       3
# NA       2
#       ...
# TT       1
# NG       1
# IT       1
# MC       1
# MY       1
# IS       1
# NO       1
# FI       1
# SK       1
# VI       1
# CY       1
# LU       1
# RU       1
# RE       1
# UY       1
# HK       1
# KH       1
# DO       1
# DK       1
# CZ       1
# DZ       1
# QA       1
# JP       1
# JM       1
# JE       1
# HT       1
# BG       1
# CM       1
# OM       1
# IL       1
# Name: venue_country, dtype: int64

# %%
df['venue_state'].value_counts()
# Out:
#                              2625
# CA                           1377
# NY                            762
# TX                            487
# FL                            406
# IL                            352
# London                        332
# MA                            259
# Ontario                       254
# Gt Lon                        252
# GA                            233
# PA                            210
# ON                            200
# NC                            197
# WA                            196
# VA                            189
# CO                            189
# OH                            181
# England                       174
# MD                            172
# NJ                            158
# DC                            153
# MI                            148
# British Columbia              142
# NSW                           135
# MN                            127
# IN                            123
# ...

# %%
df['currency'].value_counts()
# Out:
# USD    9696
# GBP    2222
# CAD    1322
# AUD     779
# EUR     262
# NZD      55
# MXN       1
# Name: currency, dtype: int64
